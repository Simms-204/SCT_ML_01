# %% [markdown]
# <a href="https://colab.research.google.com/github/Simms-204/SCT_ML_01/blob/main/examples/tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="center">
#
#   <a href="https://ultralytics.com/yolo" target="_blank">
#     <img width="1024", src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov8/banner-yolov8.png"></a>
#
#   [中文](https://docs.ultralytics.com/zh/) | [한국어](https://docs.ultralytics.com/ko/) | [日本語](https://docs.ultralytics.com/ja/) | [Русский](https://docs.ultralytics.com/ru/) | [Deutsch](https://docs.ultralytics.com/de/) | [Français](https://docs.ultralytics.com/fr/) | [Español](https://docs.ultralytics.com/es/) | [Português](https://docs.ultralytics.com/pt/) | [Türkçe](https://docs.ultralytics.com/tr/) | [Tiếng Việt](https://docs.ultralytics.com/vi/) | [العربية](https://docs.ultralytics.com/ar/)
#
#   <a href="https://github.com/ultralytics/ultralytics/actions/workflows/ci.yaml"><img src="https://github.com/ultralytics/ultralytics/actions/workflows/ci.yaml/badge.svg" alt="Ultralytics CI"></a>
#   <a href="https://console.paperspace.com/github/ultralytics/ultralytics"><img src="https://assets.paperspace.io/img/gradient-badge.svg" alt="Run on Gradient"/></a>
#   <a href="https://colab.research.google.com/github/ultralytics/ultralytics/blob/main/examples/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#   <a href="https://www.kaggle.com/models/ultralytics/yolo11"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
#
#   <a href="https://ultralytics.com/discord"><img alt="Discord" src="https://img.shields.io/discord/1089800235347353640?logo=discord&logoColor=white&label=Discord&color=blue"></a>
#   <a href="https://community.ultralytics.com"><img alt="Ultralytics Forums" src="https://img.shields.io/discourse/users?server=https%3A%2F%2Fcommunity.ultralytics.com&logo=discourse&label=Forums&color=blue"></a>
#   <a href="https://reddit.com/r/ultralytics"><img alt="Ultralytics Reddit" src="https://img.shields.io/reddit/subreddit-subscribers/ultralytics?style=flat&logo=reddit&logoColor=white&label=Reddit&color=blue"></a>
#
# Welcome to the Ultralytics YOLO11 🚀 notebook! <a href="https://github.com/ultralytics/ultralytics">YOLO11</a> is the latest version of the YOLO (You Only Look Once) AI models developed by <a href="https://ultralytics.com">Ultralytics</a>. This notebook serves as the starting point for exploring the various resources available to help you get started with YOLO11 and understand its features and capabilities.
#
# YOLO11 models are fast, accurate, and easy to use, making them ideal for various object detection and image segmentation tasks. They can be trained on large datasets and run on diverse hardware platforms, from CPUs to GPUs.
#
# We hope that the resources in this notebook will help you get the most out of YOLO11. Please browse the YOLO11 <a href="https://docs.ultralytics.com/">Docs</a> for details, raise an issue on <a href="https://github.com/ultralytics/ultralytics">GitHub</a> for support, and join our <a href="https://ultralytics.com/discord">Discord</a> community for questions and discussions!
#
#   <a href="https://www.youtube.com/watch?v=ZN3nRZT7b24" target="_blank">
#     <img src="https://img.youtube.com/vi/ZN3nRZT7b24/maxresdefault.jpg" alt="Ultralytics Video" width="720" style="border-radius: 10px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);"></a>
#
#   <p style="font-size: 16px; font-family: Arial, sans-serif; color: #555;">
#     <strong>Watch: </strong> How to Train
#   <a href="https://github.com/ultralytics/ultralytics">Ultralytics</a>
#   <a href="https://docs.ultralytics.com/models/yolo11/">YOLO11</a> Model on Custom Dataset using Google Colab Notebook 🚀</p>
# </div>

# %% [markdown]
# # Setup
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml) and check software and hardware.
#
# [![PyPI - Version](https://img.shields.io/pypi/v/ultralytics?logo=pypi&logoColor=white)](https://pypi.org/project/ultralytics/) [![Downloads](https://static.pepy.tech/badge/ultralytics)](https://www.pepy.tech/projects/ultralytics) [![PyPI - Python Version](https://img.shields.io/pypi/pyversions/ultralytics?logo=python&logoColor=gold)](https://pypi.org/project/ultralytics/)

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.55 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.7/112.6 GB disk)

# %% [markdown]
# # 1. Predict
#
# YOLO11 may be used directly in the Command Line Interface (CLI) with a `yolo` command for a variety of tasks and modes and accepts additional arguments, i.e. `imgsz=640`. See a full list of available `yolo` [arguments](https://docs.ultralytics.com/usage/cfg/) and other details in the [YOLO11 Predict Docs](https://docs.ultralytics.com/modes/train/).

# %%
# Run inference on an image with YOLO11n
# !yolo predict model=yolo11n.pt source='https://ultralytics.com/images/zidane.jpg'
# Out:
# ...
# 100% 5.35M/5.35M [00:00<00:00, 72.7MB/s]
# Ultralytics 8.3.2 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n summary (fused): 238 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# ...
# 100% 49.2k/49.2k [00:00<00:00, 5.37MB/s]
# image 1/1 /content/zidane.jpg: 384x640 2 persons, 1 tie, 63.4ms
# Speed: 14.5ms preprocess, 63.4ms inference, 820.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/212889447-69e5bdf1-5800-4e29-835e-2ed2336dede2.jpg" width="600">

# %% [markdown]
# # 2. Val
# Validate a model's accuracy on the [COCO](https://docs.ultralytics.com/datasets/detect/coco/) dataset's `val` or `test` splits. The latest YOLO11 [models](https://github.com/ultralytics/ultralytics#models) are downloaded automatically the first time they are used. See [YOLO11 Val Docs](https://docs.ultralytics.com/modes/val/) for more information.

# %%
# Download COCO val
import torch
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017val.zip', 'tmp.zip')  # download (780M - 5000 images)
# !unzip -q tmp.zip -d datasets && rm tmp.zip  # unzip
# Out:
# 100%|██████████| 780M/780M [00:09<00:00, 82.3MB/s]

# %% [markdown]
# # 3. Train
#
# <p align=""><a href="https://ultralytics.com/hub"><img width="1000" src="https://github.com/ultralytics/assets/raw/main/yolov8/banner-integrations.png"/></a></p>
#
# Train YOLO11 on [Detect](https://docs.ultralytics.com/tasks/detect/), [Segment](https://docs.ultralytics.com/tasks/segment/), [Classify](https://docs.ultralytics.com/tasks/classify/) and [Pose](https://docs.ultralytics.com/tasks/pose/) datasets. See [YOLO11 Train Docs](https://docs.ultralytics.com/modes/train/) for more information.

# %%
# Validate YOLO11n on COCO8 val
# !yolo val model=yolo11n.pt data=coco8.yaml
# Out:
# Ultralytics 8.3.2 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n summary (fused): 238 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# Dataset 'coco8.yaml' images not found ⚠️, missing path '/content/datasets/coco8/images/val'
# ...
# 100% 433k/433k [00:00<00:00, 15.8MB/s]
# Unzipping /content/datasets/coco8.zip to /content/datasets/coco8...: 100% 25/25 [00:00<00:00, 1188.35file/s]
# Dataset download success ✅ (1.4s), saved to /content/datasets
#
# ...
# 100% 755k/755k [00:00<00:00, 17.7MB/s]
# val: Scanning /content/datasets/coco8/labels/val... 4 images, 0 backgrounds, 0 corrupt: 100% 4/4 [00:00<00:00, 142.04it/s]
# val: New cache created: /content/datasets/coco8/labels/val.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:04<00:00,  4.75s/it]
#                    all          4         17       0.57       0.85      0.847      0.632
# ...

# %%
#@title Select YOLO11 🚀 logger {run: 'auto'}
logger = 'Comet' #@param ['Comet', 'TensorBoard']

if logger == 'Comet':
  # %pip install -q comet_ml
  import comet_ml; comet_ml.init()
elif logger == 'TensorBoard':
  # %load_ext tensorboard
  # %tensorboard --logdir .

# %%
# Train YOLO11n on COCO8 for 3 epochs
# !yolo train model=yolo11n.pt data=coco8.yaml epochs=3 imgsz=640
# Out:
# Ultralytics 8.3.2 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # 4. Export
#
# Export a YOLO11 model to any supported format below with the `format` argument, i.e. `format=onnx`. See [YOLO11 Export Docs](https://docs.ultralytics.com/modes/export/) for more information.
#
# - 💡 ProTip: Export to [ONNX](https://docs.ultralytics.com/integrations/onnx/) or [OpenVINO](https://docs.ultralytics.com/integrations/openvino/) for up to 3x CPU speedup.
# - 💡 ProTip: Export to [TensorRT](https://docs.ultralytics.com/integrations/tensorrt/) for up to 5x GPU speedup.
#
# | Format                                                                   | `format` Argument | Model                     | Metadata | Arguments                                                            |
# |--------------------------------------------------------------------------|-------------------|---------------------------|----------|----------------------------------------------------------------------|
# | [PyTorch](https://pytorch.org/)                                          | -                 | `yolo11n.pt`              | ✅        | -                                                                    |
# | [TorchScript](https://docs.ultralytics.com/integrations/torchscript)     | `torchscript`     | `yolo11n.torchscript`     | ✅        | `imgsz`, `optimize`, `batch`                                         |
# | [ONNX](https://docs.ultralytics.com/integrations/onnx)                   | `onnx`            | `yolo11n.onnx`            | ✅        | `imgsz`, `half`, `dynamic`, `simplify`, `opset`, `batch`             |
# | [OpenVINO](https://docs.ultralytics.com/integrations/openvino)           | `openvino`        | `yolo11n_openvino_model/` | ✅        | `imgsz`, `half`, `dynamic`, `int8`, `batch`                          |
# | [TensorRT](https://docs.ultralytics.com/integrations/tensorrt)           | `engine`          | `yolo11n.engine`          | ✅        | `imgsz`, `half`, `dynamic`, `simplify`, `workspace`, `int8`, `batch` |
# | [CoreML](https://docs.ultralytics.com/integrations/coreml)               | `coreml`          | `yolo11n.mlpackage`       | ✅        | `imgsz`, `half`, `int8`, `nms`, `batch`                              |
# | [TF SavedModel](https://docs.ultralytics.com/integrations/tf-savedmodel) | `saved_model`     | `yolo11n_saved_model/`    | ✅        | `imgsz`, `keras`, `int8`, `batch`                                    |
# | [TF GraphDef](https://docs.ultralytics.com/integrations/tf-graphdef)     | `pb`              | `yolo11n.pb`              | ❌        | `imgsz`, `batch`                                                     |
# | [TF Lite](https://docs.ultralytics.com/integrations/tflite)              | `tflite`          | `yolo11n.tflite`          | ✅        | `imgsz`, `half`, `int8`, `batch`                                     |
# | [TF Edge TPU](https://docs.ultralytics.com/integrations/edge-tpu)        | `edgetpu`         | `yolo11n_edgetpu.tflite`  | ✅        | `imgsz`                                                              |
# | [TF.js](https://docs.ultralytics.com/integrations/tfjs)                  | `tfjs`            | `yolo11n_web_model/`      | ✅        | `imgsz`, `half`, `int8`, `batch`                                     |
# | [PaddlePaddle](https://docs.ultralytics.com/integrations/paddlepaddle)   | `paddle`          | `yolo11n_paddle_model/`   | ✅        | `imgsz`, `batch`                                                     |
# | [MNN](https://docs.ultralytics.com/integrations/mnn)                     | `mnn`             | `yolo11n.mnn`             | ✅        | `imgsz`, `batch`, `int8`, `half`                                     |
# | [NCNN](https://docs.ultralytics.com/integrations/ncnn)                   | `ncnn`            | `yolo11n_ncnn_model/`     | ✅        | `imgsz`, `half`, `batch`                                             |
# | [IMX500](https://docs.ultralytics.com/integrations/sony-imx500)          | `imx`             | `yolov8n_imx_model/`      | ✅        | `imgsz`, `int8`                                                      |

# %%
# !yolo export model=yolo11n.pt format=torchscript
# Out:
# Ultralytics 8.3.2 🚀 Python-3.10.12 torch-2.4.1+cu121 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 238 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# PyTorch: starting from 'yolo11n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (5.4 MB)
#
# TorchScript: starting export with torch 2.4.1+cu121...
# TorchScript: export success ✅ 2.4s, saved as 'yolo11n.torchscript' (10.5 MB)
#
# Export complete (4.2s)
# Results saved to /content
# Predict:         yolo predict task=detect model=yolo11n.torchscript imgsz=640
# Validate:        yolo val task=detect model=yolo11n.torchscript imgsz=640 data=coco.yaml
# Visualize:       https://netron.app
# 💡 Learn more at https://docs.ultralytics.com/modes/export

# %% [markdown]
# # 5. Python Usage
#
# YOLO11 was reimagined using Python-first principles for the most seamless Python YOLO experience yet. YOLO11 models can be loaded from a trained checkpoint or created from scratch. Then methods are used to train, val, predict, and export the model. See detailed Python usage examples in the [YOLO11 Python Docs](https://docs.ultralytics.com/usage/python/).

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolo11n.yaml')  # build a new model from scratch
model = YOLO('yolo11n.pt')  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data='coco8.yaml', epochs=3)  # train the model
results = model.val()  # evaluate model performance on the validation set
results = model('https://ultralytics.com/images/bus.jpg')  # predict on an image
results = model.export(format='onnx')  # export the model to ONNX format

# %% [markdown]
# # 6. Tasks
#
# YOLO11 can train, val, predict and export models for the most common tasks in vision AI: [Detect](https://docs.ultralytics.com/tasks/detect/), [Segment](https://docs.ultralytics.com/tasks/segment/), [Classify](https://docs.ultralytics.com/tasks/classify/) and [Pose](https://docs.ultralytics.com/tasks/pose/). See [YOLO11 Tasks Docs](https://docs.ultralytics.com/tasks/) for more information.
#
# <br><img width="1024" src="https://raw.githubusercontent.com/ultralytics/assets/main/im/banner-tasks.png">

# %% [markdown]
# ## 1. Detection
#
# YOLO11 _detection_ models have no suffix and are the default YOLO11 models, i.e. `yolo11n.pt` and are pretrained on COCO. See [Detection Docs](https://docs.ultralytics.com/tasks/detect/) for full details.

# %%
# Load YOLO11n, train it on COCO128 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo11n.pt')  # load a pretrained YOLO detection model
model.train(data='coco8.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 2. Segmentation
#
# YOLO11 _segmentation_ models use the `-seg` suffix, i.e. `yolo11n-seg.pt` and are pretrained on COCO. See [Segmentation Docs](https://docs.ultralytics.com/tasks/segment/) for full details.

# %%
# Load YOLO11n-seg, train it on COCO128-seg for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo11n-seg.pt')  # load a pretrained YOLO segmentation model
model.train(data='coco8-seg.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 3. Classification
#
# YOLO11 _classification_ models use the `-cls` suffix, i.e. `yolo11n-cls.pt` and are pretrained on ImageNet. See [Classification Docs](https://docs.ultralytics.com/tasks/classify/) for full details.

# %%
# Load YOLO11n-cls, train it on mnist160 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo11n-cls.pt')  # load a pretrained YOLO classification model
model.train(data='mnist160', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 4. Pose
#
# YOLO11 _pose_ models use the `-pose` suffix, i.e. `yolo11n-pose.pt` and are pretrained on COCO Keypoints. See [Pose Docs](https://docs.ultralytics.com/tasks/pose/) for full details.

# %%
# Load YOLO11n-pose, train it on COCO8-pose for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo11n-pose.pt')  # load a pretrained YOLO pose model
model.train(data='coco8-pose.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/bus.jpg')  # predict on an image

# %% [markdown]
# ## 4. Oriented Bounding Boxes (OBB)
#
# YOLO11 _OBB_ models use the `-obb` suffix, i.e. `yolo11n-obb.pt` and are pretrained on the DOTA dataset. See [OBB Docs](https://docs.ultralytics.com/tasks/obb/) for full details.

# %%
# Load YOLO11n-obb, train it on DOTA8 for 3 epochs and predict an image with it
from ultralytics import YOLO

model = YOLO('yolo11n-obb.pt')  # load a pretrained YOLO OBB model
model.train(data='dota8.yaml', epochs=3)  # train the model
model('https://ultralytics.com/images/boats.jpg')  # predict on an image

# %% [markdown]
# # Appendix
#
# Additional content below.

# %%
# Pip install from source
# !pip install git+https://github.com/ultralytics/ultralytics@main

# %%
# Git clone and run tests on updates branch
# !git clone https://github.com/ultralytics/ultralytics -b main
# %pip install -qe ultralytics

# %%
# Run tests (Git clone only)
# !pytest ultralytics/tests

# %%
# Validate multiple models
for x in 'nsmlx':
  # !yolo val model=yolo11{x}.pt data=coco.yaml

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# Load a pre-trained YOLOv11 model
model = YOLO('yolo11n.pt')

# %%
# Install necessary libraries
# !pip install ultralytics opencv-python-headless

import cv2
import numpy as np
from ultralytics import YOLO

# Load the video
video_path = '/content/sample3with_countdetect.mp4'
cap = cv2.VideoCapture(video_path)

# Define the YOLOv11 model
model = YOLO('/content/yolo11n.pt')  # Replace with your YOLOv11 weights

# Define the ROI (left side of the frame)
def is_in_roi(x, y, roi_coords):
    x1, y1, x2, y2 = roi_coords
    return x1 <= x <= x2 and y1 <= y <= y2

# Output video writer
output_path = '/content/output_with_alerts.mp4'
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
fps = cap.get(cv2.CAP_PROP_FPS)
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

# Define ROI as left 1/4 of the frame
roi_coords = (0, 0, frame_width // 4, frame_height)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLOv11 on the frame
    results = model(frame)

    # Draw ROI
    cv2.rectangle(frame, (roi_coords[0], roi_coords[1]),
                  (roi_coords[2], roi_coords[3]), (0, 255, 0), 2)

    trespassing_detected = False
    for result in results.xyxy[0]:  # Iterate over detections
        x1, y1, x2, y2, conf, cls = result
        if cls == 0:  # Assuming '0' is the class ID for 'person'
            # Check if the center of the bounding box is in the ROI
            cx, cy = int((x1 + x2) / 2), int((y1 + y2) / 2)
            if is_in_roi(cx, cy, roi_coords):
                trespassing_detected = True
                cv2.putText(frame, 'ALERT: Trespassing',
                            (50, 50), cv2.FONT_HERSHEY_SIMPLEX,
                            1, (0, 0, 255), 2)
                cv2.rectangle(frame, (int(x1), int(y1)),
                              (int(x2), int(y2)), (0, 0, 255), 2)

    if trespassing_detected:
        print("Alert: Person detected in the ROI!")

    out.write(frame)

cap.release()
out.release()
print(f"Processed video saved to {output_path}")
# Out:
# ...
#
# 0: 384x640 1 suitcase, 95.8ms
# Speed: 15.7ms preprocess, 95.8ms inference, 809.7ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-86e86d71e317> in <cell line: 31>()
#      42
#      43     trespassing_detected = False
# ---> 44     for result in results.xyxy[0]:  # Iterate over detections
#      45         x1, y1, x2, y2, conf, cls = result
#      46         if cls == 0:  # Assuming '0' is the class ID for 'person'
#
# AttributeError: 'list' object has no attribute 'xyxy'

# %%
from ultralytics import YOLO

weights_path = '/content/yolov11n (2).pt'  # Update the path
model = YOLO(weights_path)  # Load the model
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-485c2ecd9734> in <cell line: 4>()
#       2
#       3 weights_path = '/content/yolov11n (2).pt'  # Update the path
# ----> 4 model = YOLO(weights_path)  # Load the model
#       5
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/models/yolo/model.py in __init__(self, model, task, verbose)
#      21         else:
#      22             # Continue with default YOLO initialization
# ---> 23             super().__init__(model=model, task=task, verbose=verbose)
#      24
#      25     @property
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py in __init__(self, model, task, verbose)
#     144             self._new(model, task=task, verbose=verbose)
#     145         else:
# --> 146             self._load(model, task=task)
#     147
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fa4fef56-6230-4747-9e93-dad4ae3a5b66" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fa4fef56-6230-4747-9e93-dad4ae3a5b66">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
os.listdir()
# Out:
# ['.config',
#  'yolo11n (1).pt',
#  'yolo11n (2).pt',
#  'yolov11n.pt',
#  'sample3with_countdetect.mp4',
#  'yolo11n.pt',
#  'D:',
#  'datasets']

# %%
# Install necessary libraries
# !pip install ultralytics opencv-python-headless

import os
import cv2
import numpy as np
from ultralytics import YOLO

# Define input and output paths
video_path = '/content/sample3with_countdetect.mp4'  # Colab input path
output_path = '/content/output_with_alerts.mp4'      # Colab output path

# Load the video
cap = cv2.VideoCapture(video_path)

# Load the YOLOv11 model
weights_path = '/content/yolov11n.pt'  # Ensure weights are uploaded to Colab
model = YOLO()

# Create output video writer
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
fps = cap.get(cv2.CAP_PROP_FPS)
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

# Define ROI (left 1/4th of frame)
roi_coords = (0, 0, frame_width // 4, frame_height)

# Function to check if detection is in ROI
def is_in_roi(x, y, roi_coords):
    x1, y1, x2, y2 = roi_coords
    return x1 <= x <= x2 and y1 <= y <= y2

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLOv11 on the frame
    results = model(frame)

    # Draw ROI
    cv2.rectangle(frame, (roi_coords[0], roi_coords[1]),
                  (roi_coords[2], roi_coords[3]), (0, 255, 0), 2)

    trespassing_detected = False
    for result in results.xyxy[0]:  # Iterate detections
        x1, y1, x2, y2, conf, cls = result
        if cls == 0:  # Assuming '0' is the class ID for 'person'
            # Check if bounding box center is in the ROI
            cx, cy = int((x1 + x2) / 2), int((y1 + y2) / 2)
            if is_in_roi(cx, cy, roi_coords):
                trespassing_detected = True
                cv2.putText(frame, 'ALERT: Trespassing',
                            (50, 50), cv2.FONT_HERSHEY_SIMPLEX,
                            1, (0, 0, 255), 2)
                cv2.rectangle(frame, (int(x1), int(y1)),
                              (int(x2), int(y2)), (0, 0, 255), 2)

    if trespassing_detected:
        print("Alert: Person detected in the ROI!")

    out.write(frame)

cap.release()
out.release()

print(f"Processed video saved to {output_path}")

# Download the processed video
from google.colab import files
files.download(output_path)
# Out:
# ...
#
# 0: 384x640 1 suitcase, 11.9ms
# Speed: 2.6ms preprocess, 11.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-a262371dd784> in <cell line: 35>()
#      46
#      47     trespassing_detected = False
# ---> 48     for result in results.xyxy[0]:  # Iterate detections
#      49         x1, y1, x2, y2, conf, cls = result
#      50         if cls == 0:  # Assuming '0' is the class ID for 'person'
#
# AttributeError: 'list' object has no attribute 'xyxy'

# %%
# Install necessary libraries
# !pip install ultralytics opencv-python-headless

import os
import cv2
import numpy as np
from ultralytics import YOLO

# Define input and output paths
video_path = '/content/sample3with_countdetect.mp4'  # Colab input path
output_path = '/content/output_with_alerts.mp4'      # Colab output path

# Load the video
cap = cv2.VideoCapture(video_path)

# Load the YOLOv11 model
weights_path = '/content/yolo11n.pt'  # Ensure weights are uploaded to Colab
model = YOLO(weights_path)  # Specify the weights path if needed

# Create output video writer
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
fps = cap.get(cv2.CAP_PROP_FPS)
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

# Define ROI (left 1/4th of frame)
roi_coords = (0, 0, frame_width // 4, frame_height)

# Function to check if detection is in ROI
def is_in_roi(x, y, roi_coords):
    x1, y1, x2, y2 = roi_coords
    return x1 <= x <= x2 and y1 <= y <= y2

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLOv11 on the frame
    results = model(frame)

    # Convert results to a pandas DataFrame
    df = results.pandas().xyxy[0]  # Access detection results in pandas DataFrame

    # Draw ROI
    cv2.rectangle(frame, (roi_coords[0], roi_coords[1]),
                  (roi_coords[2], roi_coords[3]), (0, 255, 0), 2)

    trespassing_detected = False
    for _, row in df.iterrows():  # Iterate through each detection
        x1, y1, x2, y2, conf, cls = row[['xmin', 'ymin', 'xmax', 'ymax', 'confidence', 'class']]

        # Check if the detected class is 'person' (class 0)
        if cls == 0:  # Assuming '0' is the class ID for 'person'
            # Calculate the center of the bounding box
            cx, cy = int((x1 + x2) / 2), int((y1 + y2) / 2)
            if is_in_roi(cx, cy, roi_coords):
                trespassing_detected = True
                # Add a text alert for trespassing
                cv2.putText(frame, 'ALERT: Trespassing',
                            (50, 50), cv2.FONT_HERSHEY_SIMPLEX,
                            1, (0, 0, 255), 2)
                cv2.rectangle(frame, (int(x1), int(y1)),
                              (int(x2), int(y2)), (0, 0, 255), 2)

    if trespassing_detected:
        print("Alert: Person detected in the ROI!")

    out.write(frame)

cap.release()
out.release()

print(f"Processed video saved to {output_path}")

# Download the processed video
from google.colab import files
files.download(output_path)
# Out:
# ...
#
# 0: 384x640 1 suitcase, 12.3ms
# Speed: 1.9ms preprocess, 12.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-635f7e5db6ff> in <cell line: 35>()
#      42
#      43     # Convert results to a pandas DataFrame
# ---> 44     df = results.pandas().xyxy[0]  # Access detection results in pandas DataFrame
#      45
#      46     # Draw ROI
#
# AttributeError: 'list' object has no attribute 'pandas'

# %%
# Install necessary libraries
# !pip install ultralytics opencv-python-headless

import os
import cv2
import numpy as np
from ultralytics import YOLO

# Define input and output paths
video_path = '/content/sample3with_countdetect.mp4'  # Colab input path
output_path = '/content/output_with_alerts.mp4'      # Colab output path

# Load the video
cap = cv2.VideoCapture(video_path)

# Load the YOLOv11 model
weights_path = '/content/yolo11n.pt'  # Ensure weights are uploaded to Colab
model = YOLO(weights_path)  # Specify the weights path if needed

# Create output video writer
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
fps = cap.get(cv2.CAP_PROP_FPS)
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

# Define ROI (left 1/4th of frame)
roi_coords = (0, 0, frame_width // 4, frame_height)

# Function to check if detection is in ROI
def is_in_roi(x, y, roi_coords):
    x1, y1, x2, y2 = roi_coords
    return x1 <= x <= x2 and y1 <= y <= y2

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLOv11 on the frame
    results = model(frame)

    # Get the detections from the results
    detections = results[0].boxes  # List of boxes for the first image in the batch

    # Draw ROI
    cv2.rectangle(frame, (roi_coords[0], roi_coords[1]),
                  (roi_coords[2], roi_coords[3]), (0, 255, 0), 2)

    trespassing_detected = False
    for detection in detections:  # Iterate through each detection
        x1, y1, x2, y2, conf, cls = detection.xyxy[0].cpu().numpy()  # Get detection coordinates

        # Check if the detected class is 'person' (class 0)
        if cls == 0:  # Assuming '0' is the class ID for 'person'
            # Calculate the center of the bounding box
            cx, cy = int((x1 + x2) / 2), int((y1 + y2) / 2)
            if is_in_roi(cx, cy, roi_coords):
                trespassing_detected = True
                # Add a text alert for trespassing
                cv2.putText(frame, 'ALERT: Trespassing',
                            (50, 50), cv2.FONT_HERSHEY_SIMPLEX,
                            1, (0, 0, 255), 2)
                cv2.rectangle(frame, (int(x1), int(y1)),
                              (int(x2), int(y2)), (0, 0, 255), 2)

    if trespassing_detected:
        print("Alert: Person detected in the ROI!")

    out.write(frame)

cap.release()
out.release()

print(f"Processed video saved to {output_path}")

# Download the processed video
from google.colab import files
files.download(output_path)
# Out:
# ...
#
# 0: 384x640 1 suitcase, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-44c61b7299f1> in <cell line: 35>()
#      50     trespassing_detected = False
#      51     for detection in detections:  # Iterate through each detection
# ---> 52         x1, y1, x2, y2, conf, cls = detection.xyxy[0].cpu().numpy()  # Get detection coordinates
#      53
#      54         # Check if the detected class is 'person' (class 0)
#
# ValueError: not enough values to unpack (expected 6, got 4)

# %%
# Install necessary libraries
# !pip install ultralytics opencv-python-headless

import os
import cv2
import numpy as np
from ultralytics import YOLO

# Define input and output paths
video_path = '/content/sample3with_countdetect.mp4'  # Colab input path
output_path = '/content/output_with_alerts.mp4'      # Colab output path

# Load the video
cap = cv2.VideoCapture(video_path)

# Load the YOLOv11 model
weights_path = '/content/yolo11n.pt'  # Ensure weights are uploaded to Colab
model = YOLO(weights_path)  # Specify the weights path if needed

# Create output video writer
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
fps = cap.get(cv2.CAP_PROP_FPS)
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

# Define ROI (left 1/4th of frame)
roi_coords = (0, 0, frame_width // 4, frame_height)

# Function to check if detection is in ROI
def is_in_roi(x, y, roi_coords):
    x1, y1, x2, y2 = roi_coords
    return x1 <= x <= x2 and y1 <= y <= y2

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLOv11 on the frame
    results = model(frame)

    # Get the detections from the results
    detections = results[0].boxes  # List of boxes for the first image in the batch

    # Draw ROI
    cv2.rectangle(frame, (roi_coords[0], roi_coords[1]),
                  (roi_coords[2], roi_coords[3]), (0, 255, 0), 2)

    trespassing_detected = False
    for detection in detections:  # Iterate through each detection
        # Ensure that the detection has at least 6 values to unpack
        if len(detection.xyxy[0].cpu().numpy()) == 6:
            x1, y1, x2, y2, conf, cls = detection.xyxy[0].cpu().numpy()  # Get detection coordinates
        else:
            continue  # Skip this detection if it doesn't have the expected number of values

        # Check if the detected class is 'person' (class 0)
        if cls == 0:  # Assuming '0' is the class ID for 'person'
            # Calculate the center of the bounding box
            cx, cy = int((x1 + x2) / 2), int((y1 + y2) / 2)
            if is_in_roi(cx, cy, roi_coords):
                trespassing_detected = True
                # Add a text alert for trespassing
                cv2.putText(frame, 'ALERT: Trespassing',
                            (50, 50), cv2.FONT_HERSHEY_SIMPLEX,
                            1, (0, 0, 255), 2)
                cv2.rectangle(frame, (int(x1), int(y1)),
                              (int(x2), int(y2)), (0, 0, 255), 2)

    if trespassing_detected:
        print("Alert: Person detected in the ROI!")

    out.write(frame)

cap.release()
out.release()

print(f"Processed video saved to {output_path}")

# Download the processed video
from google.colab import files
files.download(output_path)
# Out:
# ...
#
# 0: 384x640 1 suitcase, 12.9ms
# Speed: 1.9ms preprocess, 12.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 suitcases, 9.2ms
# Speed: 3.0ms preprocess, 9.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 couch, 10.8ms
# Speed: 2.3ms preprocess, 10.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 couch, 8.7ms
# Speed: 2.4ms preprocess, 8.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 couch, 8.5ms
# Speed: 2.1ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 couch, 1 tv, 8.6ms
# Speed: 1.5ms preprocess, 8.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 suitcases, 1 tv, 16.6ms
# Speed: 2.4ms preprocess, 16.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
# Install necessary libraries
# !pip install ultralytics opencv-python-headless

import os
import cv2
import numpy as np
from ultralytics import YOLO

# Define input and output paths
video_path = '/content/sample3with_countdetect.mp4'  # Colab input path
output_path = '/content/output_with_alerts2.mp4'      # Colab output path

# Load the video
cap = cv2.VideoCapture(video_path)

# Load the YOLOv11 model
weights_path = '/content/yolo11n.pt'  # Ensure weights are uploaded to Colab
model = YOLO(weights_path)  # Specify the weights path if needed

# Create output video writer
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
fps = cap.get(cv2.CAP_PROP_FPS)
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

# Define ROI (left 1/4th of frame)
roi_coords = (0, 0, frame_width // 4, frame_height)

# Function to check if detection is in ROI
def is_in_roi(x, y, roi_coords):
    x1, y1, x2, y2 = roi_coords
    return x1 <= x <= x2 and y1 <= y <= y2

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLOv11 on the frame
    results = model(frame)

    # Get the detections from the results
    detections = results[0].boxes  # List of boxes for the first image in the batch

    # Draw ROI
    cv2.rectangle(frame, (roi_coords[0], roi_coords[1]),
                  (roi_coords[2], roi_coords[3]), (0, 255, 0), 2)

    trespassing_detected = False
    for detection in detections:  # Iterate through each detection
        # Ensure that the detection has at least 6 values to unpack
        if len(detection.xyxy[0].cpu().numpy()) == 6:
            x1, y1, x2, y2, conf, cls = detection.xyxy[0].cpu().numpy()  # Get detection coordinates
        else:
            continue  # Skip this detection if it doesn't have the expected number of values

        # Check if the detected class is 'person' (class 0)
        if cls == 0:  # Assuming '0' is the class ID for 'person'
            # Calculate the center of the bounding box
            cx, cy = int((x1 + x2) / 2), int((y1 + y2) / 2)
            if is_in_roi(cx, cy, roi_coords):
                trespassing_detected = True
                # Add a text alert for trespassing
                cv2.putText(frame, 'ALERT: Trespassing',
                            (50, 50), cv2.FONT_HERSHEY_SIMPLEX,
                            1, (0, 0, 255), 2)
                cv2.rectangle(frame, (int(x1), int(y1)),
                              (int(x2), int(y2)), (0, 0, 255), 2)

    out.write(frame)

cap.release()
out.release()

print(f"Processed video saved to {output_path}")

# Download the processed video
from google.colab import files
files.download(output_path)
# Out:
# ...
#
# 0: 384x640 1 suitcase, 11.5ms
# Speed: 1.8ms preprocess, 11.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 suitcases, 8.6ms
# Speed: 1.7ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 couch, 8.5ms
# Speed: 2.3ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 couch, 8.2ms
# Speed: 2.2ms preprocess, 8.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 couch, 8.7ms
# Speed: 1.6ms preprocess, 8.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 suitcase, 1 couch, 1 tv, 8.4ms
# Speed: 1.6ms preprocess, 8.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 suitcases, 1 tv, 8.9ms
# Speed: 2.4ms preprocess, 8.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
# Install necessary libraries
# !pip install ultralytics opencv-python-headless

import os
import cv2
import numpy as np
from ultralytics import YOLO

# Define input and output paths
video_path = '/content/sample1with_countdetect.mp4'  # Colab input path
output_path = '/content/output_with_alerts4.mp4'     # Colab output path

# Load the video
cap = cv2.VideoCapture(video_path)

# Load the YOLOv11 model
weights_path = '/content/yolo11n.pt'  # Ensure weights are uploaded to Colab
model = YOLO(weights_path)  # Specify the weights path if needed

# Create output video writer
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
fps = cap.get(cv2.CAP_PROP_FPS)
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

# Define ROI (top left corner of frame, large enough to be visible)
roi_coords = (0, 0, frame_width // 2, frame_height // 2)

# Function to check if detection is in ROI
def is_in_roi(x, y, roi_coords):
    x1, y1, x2, y2 = roi_coords
    return x1 <= x <= x2 and y1 <= y <= y2

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLOv11 on the frame
    results = model(frame)

    # Get the detections from the results
    detections = results[0].boxes  # List of boxes for the first image in the batch

    # Draw ROI
    cv2.rectangle(frame, (roi_coords[0], roi_coords[1]),
                  (roi_coords[2], roi_coords[3]), (0, 255, 0), 2)

    trespassing_detected = False
    for detection in detections:  # Iterate through each detection
        # Ensure that the detection has at least 6 values to unpack
        if len(detection.xyxy[0].cpu().numpy()) == 6:
            x1, y1, x2, y2, conf, cls = detection.xyxy[0].cpu().numpy()  # Get detection coordinates
        else:
            continue  # Skip this detection if it doesn't have the expected number of values

        # Check if the detected class is 'person' (class 0)
        if cls == 0:  # Assuming '0' is the class ID for 'person'
            # Calculate the center of the bounding box
            cx, cy = int((x1 + x2) / 2), int((y1 + y2) / 2)
            if is_in_roi(cx, cy, roi_coords):
                trespassing_detected = True
                # Add a text alert for trespassing
                cv2.putText(frame, 'ALERT: Trespassing',
                            (50, 50), cv2.FONT_HERSHEY_SIMPLEX,
                            1, (0, 0, 255), 2)
                cv2.rectangle(frame, (int(x1), int(y1)),
                              (int(x2), int(y2)), (0, 0, 255), 2)

    out.write(frame)

cap.release()
out.release()

print(f"Processed video saved to {output_path}")

# Download the processed video
from google.colab import files
files.download(output_path)
# Out:
# ...
#
# 0: 384x640 1 tv, 8.8ms
# Speed: 1.9ms preprocess, 8.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 11.6ms
# Speed: 3.3ms preprocess, 11.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 13.0ms
# Speed: 3.4ms preprocess, 13.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 11.1ms
# Speed: 3.3ms preprocess, 11.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 10.1ms
# Speed: 5.5ms preprocess, 10.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 9.3ms
# Speed: 6.7ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 10.4ms
# Speed: 3.4ms preprocess, 10.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 10.0ms
# ...

# %%
# Install necessary libraries
# !pip install ultralytics opencv-python-headless

import os
import cv2
import numpy as np
from ultralytics import YOLO

# Define input and output paths
video_path = '/content/sample1with_countdetect.mp4'  # Colab input path
output_path = '/content/output_with_alerts5.mp4'     # Colab output path

# Load the video
cap = cv2.VideoCapture(video_path)

# Load the YOLOv11 model
weights_path = '/content/yolo11n.pt'  # Ensure weights are uploaded to Colab
model = YOLO(weights_path)  # Specify the weights path if needed

# Create output video writer
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
fps = cap.get(cv2.CAP_PROP_FPS)
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

# Define ROI (top left corner of frame, large enough to be visible)
roi_coords = (0, 0, frame_width // 2, frame_height // 2)

# Function to check if detection is in ROI
def is_in_roi(x, y, roi_coords):
    x1, y1, x2, y2 = roi_coords
    return x1 <= x <= x2 and y1 <= y <= y2

total_people_in_roi = 0

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLOv11 on the frame
    results = model(frame)

    # Get the detections from the results
    detections = results[0].boxes  # List of boxes for the first image in the batch

    # Draw ROI
    cv2.rectangle(frame, (roi_coords[0], roi_coords[1]),
                  (roi_coords[2], roi_coords[3]), (0, 255, 0), 2)

    people_count_in_roi = 0
    for detection in detections:  # Iterate through each detection
        # Ensure that the detection has at least 6 values to unpack
        if len(detection.xyxy[0].cpu().numpy()) == 6:
            x1, y1, x2, y2, conf, cls = detection.xyxy[0].cpu().numpy()  # Get detection coordinates
        else:
            continue  # Skip this detection if it doesn't have the expected number of values

        # Check if the detected class is 'person' (class 0)
        if cls == 0:  # Assuming '0' is the class ID for 'person'
            # Calculate the center of the bounding box
            cx, cy = int((x1 + x2) / 2), int((y1 + y2) / 2)
            if is_in_roi(cx, cy, roi_coords):
                people_count_in_roi += 1
                # Add a text alert for trespassing
                cv2.putText(frame, 'ALERT: Trespassing',
                            (50, 50), cv2.FONT_HERSHEY_SIMPLEX,
                            1, (0, 0, 255), 2)
                cv2.rectangle(frame, (int(x1), int(y1)),
                              (int(x2), int(y2)), (0, 0, 255), 2)

    if people_count_in_roi > 0:
        cv2.putText(frame, f'Number of People in ROI: {people_count_in_roi}',
                    (50, 100), cv2.FONT_HERSHEY_SIMPLEX,
                    1, (0, 0, 255), 2)  # Display the number of people in ROI

    total_people_in_roi += people_count_in_roi  # Keep track of the total count across frames

    out.write(frame)

cap.release()
out.release()

print(f"Processed video saved to {output_path}")
print(f"Total people detected in ROI: {total_people_in_roi}")

# Download the processed video
from google.colab import files
files.download(output_path)
# Out:
# ...
#
# 0: 384x640 1 tv, 15.4ms
# Speed: 3.2ms preprocess, 15.4ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 15.4ms
# Speed: 3.7ms preprocess, 15.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 16.8ms
# Speed: 3.6ms preprocess, 16.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 11.6ms
# Speed: 3.1ms preprocess, 11.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 12.0ms
# Speed: 3.2ms preprocess, 12.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 12.0ms
# Speed: 3.1ms preprocess, 12.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 11.7ms
# Speed: 3.7ms preprocess, 11.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 11.2ms
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('/content/yolo11n.pt')  # Adjust the path if necessary

# Open the video file
cap = cv2.VideoCapture('/content/video.mp4')

# Get video properties
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)

# Define the codec and create VideoWriter object
out = cv2.VideoWriter('output_with_trespassing_alert.mp4', cv2.VideoWriter_fourcc(*'mp4v'), fps, (frame_width, frame_height))

# Define ROI (top left corner of frame, large enough to be visible)
roi_coords = (0, 0, frame_width // 2, frame_height // 2)

# Function to check if detection is in ROI
def is_in_roi(x, y, roi_coords):
    x1, y1, x2, y2 = roi_coords
    return x1 <= x <= x2 and y1 <= y <= y2

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Perform detection
    results = model(frame)

    # Get the detections from the results
    detections = results[0].boxes  # List of boxes for the first image in the batch

    # Count the number of detected persons (class 0) in the ROI
    person_count_in_roi = 0
    for detection in detections.data:  # Iterate through each detection
        x1, y1, x2, y2, conf, cls = detection.cpu().numpy()  # Get detection coordinates

        # Check if the detected class is 'person' (class 0)
        if int(cls) == 0:
            # Calculate center of the bounding box
            cx, cy = int((x1 + x2) / 2), int((y1 + y2) / 2)
            if is_in_roi(cx, cy, roi_coords):
                person_count_in_roi += 1
                # Add a text alert for trespassing
                cv2.putText(frame, 'ALERT: Trespassing', (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
                cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 0, 255), 2)
            else:
                # Draw bounding box for detected persons outside ROI
                cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)

    # Draw ROI on the frame
    cv2.rectangle(frame, (roi_coords[0], roi_coords[1]), (roi_coords[2], roi_coords[3]), (0, 255, 0), 2)

    # Overlay the count on the frame
    if person_count_in_roi > 0:
        cv2.putText(frame, f'Trespassing Detected: {person_count_in_roi} persons', (20, 110), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)

    # Write the frame to the output video
    out.write(frame)

    # Optional: Display the frame (can be commented out if not needed)
    #cv2_imshow('Frame', frame)
    #if cv2.waitKey(1) & 0xFF == ord('q'):
    #    break

# Release everything
cap.release()
out.release()
cv2.destroyAllWindows()

print(f"Processed video saved to output_with_trespassing_alert.mp4")
# Out:
# 0: 384x640 1 tv, 13.0ms
# Speed: 3.8ms preprocess, 13.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 9.2ms
# Speed: 2.8ms preprocess, 9.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 7.9ms
# Speed: 2.9ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 tvs, 8.1ms
# Speed: 2.6ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 tvs, 8.0ms
# Speed: 2.6ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 tvs, 9.7ms
# Speed: 2.4ms preprocess, 9.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 tvs, 8.2ms
# Speed: 2.3ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 tvs, 7.9ms
# ...
